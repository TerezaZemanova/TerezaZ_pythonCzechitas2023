# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = "/Users/tereza/Czechitas Pandas/platy_2021_02.csv"
platy = pd.read_csv(url, index_col="cislo_zamestnance")
platy
# Out:
#                       plat
# cislo_zamestnance
# 3                  54900.0
# 6                  54800.0
# 7                  36400.0
# 8                  47900.0
# 16                 34200.0
# 18                 35400.0
# 21                 54200.0
# 22                 34400.0
# 23                 39000.0
# 24                 44200.0
# 26                 59600.0
# 27                 45100.0
# 28                 38100.0
# 29                 48900.0
# 30                 33500.0
# 32                 53000.0
# 33                 38400.0
# 34                 36800.0
# 38                 32600.0
# 40                 32800.0
# 41                 49300.0
# 44                 52000.0
# 47                 40700.0
# 49                 58400.0
# 51                 37100.0
# 56                 39300.0
# 57                 36800.0
# 63                 31400.0
# 64                 36900.0
# 69                 32600.0
# 70                 52600.0
# 74                 49300.0
# ...

# %%
urceni_min_max = platy["plat"]

print(f"Nejnižší plat je {urceni_min_max.min()}.")
print(f"Nejvyšší plat je {urceni_min_max.max()}.")
# Out:
# Nejnižší plat je 31400.0.
# Nejvyšší plat je 59600.0.

# %%
platy.hist(bins=[30000, 32500, 35000, 37500, 40000, 42500, 45000, 47500, 50000, 52500, 55000, 57500, 60000])

plt.show()
